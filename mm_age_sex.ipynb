# %%
# THE PURPOSE OF THIS SCRIPT IS TO:

# 1) TAKE THE INDIVIDUAL DATASET (CONTAINING A ROW FOR EVERY CHILD) AND DERIVE A NEW TABLE WITH ONE ROW 
#    PER AGE-SEX GROUP (WHERE AN INDIVIDUAL CHILD IS CLASSIFIED BASED ON THEIR AGE-SEX GROUP AT FIRST CHECK-UP) THAT SHOWCASES PROGRESS 
#    FOR EACH AGE-SEX GROUP THROUGH AVERAGE CHANGE IN HEIGHT-FOR-AGE Z-SCORE

# 2) RUN A STATISTICAL TEST THAT INVESTIGATES WHETHER ANY OF THE AGE-SEX GROUPS DIFFER FROM EACH OTHER IN THEIR AVERAGE CHANGE IN 
#    HEIGHT-FOR-AGE Z-SCORE

# %%
# IMPORTING PACKAGES
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.sandbox.stats.multicomp import MultiComparison
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# READING IN DATASET WITH ONE ROW FOR EVERY CHECK-UP
mm_data = pd.read_excel("/Users/ajarbuckle/Desktop/MM PROJECT/mm_data_redo/mm_data_individual_table.xlsx") 
mm_data
# Out:
#       ID                       nombre_del_niño fecha_de_nacimiento  \
# 0      1             Maybelin Alicia Aju López          2016-02-22
# 1      2                Samuel David Alva Alva          2015-09-19
# 2      3                      Miriam Tulul Bac          2017-01-25
# 3      4          Cristian Anibal Avila Chávez          2019-03-21
# 4      5             Diego Alejandro Tzaj Chox          2019-01-08
# ..   ...                                   ...                 ...
# 419  535  Erikca Maria Rosalina Leal Quisquina          2016-09-28
# 420  536                Rudy Gabriel Ajú López          2015-12-22
# 421  538          Nataly Ileana Leal Quisquina          2014-08-06
# 422  544              Eduardo Valeriano Chávez          2015-07-13
# 423  554       Victor Ehidan Tomás Puac Ulario          2018-09-12
#
#           comunidad sexo monitoreo_prim monitoreo_ult  talla_prim  talla_ult  \
# 0        Los Planes    F     2017-08-15    2019-10-25        70.5       87.3
# 1             Pahaj    M     2017-12-06    2020-01-15        76.4       92.5
# 2             Pahaj    F     2018-10-19    2021-12-08        72.5       95.6
# 3         Xesampual    M     2019-07-03    2021-12-08        62.0       90.0
# 4         Xesampual    M     2019-05-15    2019-07-31        56.4       61.0
# ..              ...  ...            ...           ...         ...        ...
# 419  Ciénaga Grande    F     2019-03-13    2019-04-10        84.7       85.8
# 420  Ciénaga Grande    M     2019-03-13    2019-04-10        85.6       85.8
# 421  Ciénaga Grande    F     2019-03-13    2019-04-10        99.2       99.0
# 422        Nikajkim    M     2019-03-13    2019-04-24        97.0       97.2
# 423          Cruz B    M     2019-03-13    2019-04-10        63.3       64.5
#
#        z_prim     z_ult  observaciones  talla_dif     z_dif  \
# 0   -3.219024 -3.135741             10       16.8  0.083283
# 1   -3.906698 -2.904418             11       16.1  1.002280
# 2   -3.386637 -2.724794              9       23.1  0.661844
# 3    0.279202 -0.961131             16       28.0 -1.240333
# 4   -3.597655 -3.094706              4        4.6  0.502948
# ..        ...       ...            ...        ...       ...
# 419 -1.493608 -1.382273              2        1.1  0.111335
# 420 -3.100616 -3.178239              2        0.2 -0.077623
# 421 -1.646368 -1.795524              2       -0.2 -0.149155
# 422 -0.861285 -1.082725              2        0.2 -0.221440
# 423 -1.232583 -1.459422              2        1.2 -0.226838
#
#      monitoreo_prim_edad  duración  z_dif_rate  frecuencia  stunted_at_first  \
# 0               1.478439  2.193018    0.037976    4.559925              True
# 1               2.214921  2.108145    0.475432    5.217857              True
# 2               1.730322  3.137577    0.210941    2.868455              True
# 3               0.284736  2.433949   -0.509597    6.573678             False
# 4               0.347707  0.210815    2.385739   18.974026              True
# ..                   ...       ...         ...         ...               ...
# 419             2.453114  0.076660    1.452326   26.089286             False
# 420             3.222450  0.076660   -1.012568   26.089286              True
# 421             4.599589  0.076660   -1.945679   26.089286             False
# 422             3.665982  0.114990   -1.925733   17.392857             False
# 423             0.498289  0.076660   -2.959022   26.089286             False
#
#      stunted_at_end
# 0              True
# 1              True
# 2              True
# 3             False
# 4              True
# ..              ...
# 419           False
# 420            True
# 421           False
# 422           False
# 423           False
#
# [424 rows x 20 columns]

# %%
# CREATING AN AGE GROUP COLUMN 

# DEFINING CONDITIONS AND VALUES FOR THE CREATION OF AN AGE GROUP COLUMN
values = ['0-1', '1-2', '2-3', '3-4', '4-5']
conditions = [
    (mm_data['monitoreo_prim_edad'] < 1),
    (mm_data['monitoreo_prim_edad'] >= 1) & (mm_data['monitoreo_prim_edad'] < 2),
    (mm_data['monitoreo_prim_edad'] >= 2) & (mm_data['monitoreo_prim_edad'] < 3),
    (mm_data['monitoreo_prim_edad'] >= 3) & (mm_data['monitoreo_prim_edad'] < 4),
    (mm_data['monitoreo_prim_edad'] >= 4) & (mm_data['monitoreo_prim_edad'] < 5)
]

# CREATING THE AGE GROUP COLUMN WITH THE DEFINED CONDITIONS AND VALUES 
mm_data['age_group'] = np.select(conditions, values, default = "5+")
mm_data
# Out:
#       ID                       nombre_del_niño fecha_de_nacimiento  \
# 0      1             Maybelin Alicia Aju López          2016-02-22
# 1      2                Samuel David Alva Alva          2015-09-19
# 2      3                      Miriam Tulul Bac          2017-01-25
# 3      4          Cristian Anibal Avila Chávez          2019-03-21
# 4      5             Diego Alejandro Tzaj Chox          2019-01-08
# ..   ...                                   ...                 ...
# 419  535  Erikca Maria Rosalina Leal Quisquina          2016-09-28
# 420  536                Rudy Gabriel Ajú López          2015-12-22
# 421  538          Nataly Ileana Leal Quisquina          2014-08-06
# 422  544              Eduardo Valeriano Chávez          2015-07-13
# 423  554       Victor Ehidan Tomás Puac Ulario          2018-09-12
#
#           comunidad sexo monitoreo_prim monitoreo_ult  talla_prim  talla_ult  \
# 0        Los Planes    F     2017-08-15    2019-10-25        70.5       87.3
# 1             Pahaj    M     2017-12-06    2020-01-15        76.4       92.5
# 2             Pahaj    F     2018-10-19    2021-12-08        72.5       95.6
# 3         Xesampual    M     2019-07-03    2021-12-08        62.0       90.0
# 4         Xesampual    M     2019-05-15    2019-07-31        56.4       61.0
# ..              ...  ...            ...           ...         ...        ...
# 419  Ciénaga Grande    F     2019-03-13    2019-04-10        84.7       85.8
# 420  Ciénaga Grande    M     2019-03-13    2019-04-10        85.6       85.8
# 421  Ciénaga Grande    F     2019-03-13    2019-04-10        99.2       99.0
# 422        Nikajkim    M     2019-03-13    2019-04-24        97.0       97.2
# 423          Cruz B    M     2019-03-13    2019-04-10        63.3       64.5
#
#        z_prim  ...  observaciones  talla_dif     z_dif  monitoreo_prim_edad  \
# 0   -3.219024  ...             10       16.8  0.083283             1.478439
# 1   -3.906698  ...             11       16.1  1.002280             2.214921
# 2   -3.386637  ...              9       23.1  0.661844             1.730322
# 3    0.279202  ...             16       28.0 -1.240333             0.284736
# 4   -3.597655  ...              4        4.6  0.502948             0.347707
# ..        ...  ...            ...        ...       ...                  ...
# 419 -1.493608  ...              2        1.1  0.111335             2.453114
# 420 -3.100616  ...              2        0.2 -0.077623             3.222450
# 421 -1.646368  ...              2       -0.2 -0.149155             4.599589
# 422 -0.861285  ...              2        0.2 -0.221440             3.665982
# 423 -1.232583  ...              2        1.2 -0.226838             0.498289
#
#      duración  z_dif_rate  frecuencia  stunted_at_first  stunted_at_end  \
# 0    2.193018    0.037976    4.559925              True            True
# 1    2.108145    0.475432    5.217857              True            True
# 2    3.137577    0.210941    2.868455              True            True
# 3    2.433949   -0.509597    6.573678             False           False
# 4    0.210815    2.385739   18.974026              True            True
# ..        ...         ...         ...               ...             ...
# 419  0.076660    1.452326   26.089286             False           False
# 420  0.076660   -1.012568   26.089286              True            True
# 421  0.076660   -1.945679   26.089286             False           False
# 422  0.114990   -1.925733   17.392857             False           False
# 423  0.076660   -2.959022   26.089286             False           False
#
#      age_group
# 0          1-2
# 1          2-3
# 2          1-2
# 3          0-1
# 4          0-1
# ..         ...
# 419        2-3
# 420        3-4
# 421        4-5
# 422        3-4
# 423        0-1
#
# [424 rows x 21 columns]

# %%
# CREATING A NEW COLUMN FOR AGE-SEX GROUPS, WHICH IS JUST CONCATENATING THE ALREADY PRESENT AGE AND SEX COLUMNS
mm_data['age_sex_group'] = mm_data['sexo'] + ' ' + mm_data['age_group'] + ' Years'
mm_data
# Out:
#       ID                       nombre_del_niño fecha_de_nacimiento  \
# 0      1             Maybelin Alicia Aju López          2016-02-22
# 1      2                Samuel David Alva Alva          2015-09-19
# 2      3                      Miriam Tulul Bac          2017-01-25
# 3      4          Cristian Anibal Avila Chávez          2019-03-21
# 4      5             Diego Alejandro Tzaj Chox          2019-01-08
# ..   ...                                   ...                 ...
# 419  535  Erikca Maria Rosalina Leal Quisquina          2016-09-28
# 420  536                Rudy Gabriel Ajú López          2015-12-22
# 421  538          Nataly Ileana Leal Quisquina          2014-08-06
# 422  544              Eduardo Valeriano Chávez          2015-07-13
# 423  554       Victor Ehidan Tomás Puac Ulario          2018-09-12
#
#           comunidad sexo monitoreo_prim monitoreo_ult  talla_prim  talla_ult  \
# 0        Los Planes    F     2017-08-15    2019-10-25        70.5       87.3
# 1             Pahaj    M     2017-12-06    2020-01-15        76.4       92.5
# 2             Pahaj    F     2018-10-19    2021-12-08        72.5       95.6
# 3         Xesampual    M     2019-07-03    2021-12-08        62.0       90.0
# 4         Xesampual    M     2019-05-15    2019-07-31        56.4       61.0
# ..              ...  ...            ...           ...         ...        ...
# 419  Ciénaga Grande    F     2019-03-13    2019-04-10        84.7       85.8
# 420  Ciénaga Grande    M     2019-03-13    2019-04-10        85.6       85.8
# 421  Ciénaga Grande    F     2019-03-13    2019-04-10        99.2       99.0
# 422        Nikajkim    M     2019-03-13    2019-04-24        97.0       97.2
# 423          Cruz B    M     2019-03-13    2019-04-10        63.3       64.5
#
#        z_prim  ...  talla_dif     z_dif  monitoreo_prim_edad  duración  \
# 0   -3.219024  ...       16.8  0.083283             1.478439  2.193018
# 1   -3.906698  ...       16.1  1.002280             2.214921  2.108145
# 2   -3.386637  ...       23.1  0.661844             1.730322  3.137577
# 3    0.279202  ...       28.0 -1.240333             0.284736  2.433949
# 4   -3.597655  ...        4.6  0.502948             0.347707  0.210815
# ..        ...  ...        ...       ...                  ...       ...
# 419 -1.493608  ...        1.1  0.111335             2.453114  0.076660
# 420 -3.100616  ...        0.2 -0.077623             3.222450  0.076660
# 421 -1.646368  ...       -0.2 -0.149155             4.599589  0.076660
# 422 -0.861285  ...        0.2 -0.221440             3.665982  0.114990
# 423 -1.232583  ...        1.2 -0.226838             0.498289  0.076660
#
#      z_dif_rate  frecuencia  stunted_at_first  stunted_at_end  age_group  \
# 0      0.037976    4.559925              True            True        1-2
# 1      0.475432    5.217857              True            True        2-3
# 2      0.210941    2.868455              True            True        1-2
# 3     -0.509597    6.573678             False           False        0-1
# 4      2.385739   18.974026              True            True        0-1
# ..          ...         ...               ...             ...        ...
# 419    1.452326   26.089286             False           False        2-3
# 420   -1.012568   26.089286              True            True        3-4
# 421   -1.945679   26.089286             False           False        4-5
# 422   -1.925733   17.392857             False           False        3-4
# 423   -2.959022   26.089286             False           False        0-1
#
#      age_sex_group
# 0      F 1-2 Years
# 1      M 2-3 Years
# 2      F 1-2 Years
# 3      M 0-1 Years
# 4      M 0-1 Years
# ..             ...
# 419    F 2-3 Years
# 420    M 3-4 Years
# 421    F 4-5 Years
# 422    M 3-4 Years
# 423    M 0-1 Years
#
# [424 rows x 22 columns]

# %%
# CREATING THE NEW TABLE WITH INFORMATION ON EVERY SEX-AGE GROUP
age_sex_table = mm_data.groupby('age_sex_group').agg(
    total_kids = ('ID', lambda x: x.nunique()),
    avg_z_dif_rate =('z_dif_rate', 'mean')
    )

# ROUNDING VALUES TO MAKE THE FINAL TABLE LOOK NICER 
age_sex_table['avg_z_dif_rate'] = age_sex_table['avg_z_dif_rate'].round(2)

age_sex_table
# Out:
#                total_kids  avg_z_dif_rate
# age_sex_group
# F 0-1 Years            93           -0.36
# F 1-2 Years            60           -0.20
# F 2-3 Years            35           -0.05
# F 3-4 Years            21            0.13
# F 4-5 Years            12            0.16
# M 0-1 Years           101           -0.25
# M 1-2 Years            51            0.14
# M 2-3 Years            27           -0.03
# M 3-4 Years            18           -0.14
# M 4-5 Years             6           -0.12

# %%
# NOW GOING BACK TO THE DATASET WITH ONE ROW PER CHILD TO RUN THE STATISTICAL TEST TO SEE IF THERE ARE STATISTICALLY SIGNIFICANT DIFFERENCES IN RATE OF CHANGE 
# OF HEIGHT-FOR-AGE Z-SCORE OVER TIME BETWEEN AGE-SEX GROUPS  

mm_data
# Out:
#       ID                       nombre_del_niño fecha_de_nacimiento  \
# 0      1             Maybelin Alicia Aju López          2016-02-22
# 1      2                Samuel David Alva Alva          2015-09-19
# 2      3                      Miriam Tulul Bac          2017-01-25
# 3      4          Cristian Anibal Avila Chávez          2019-03-21
# 4      5             Diego Alejandro Tzaj Chox          2019-01-08
# ..   ...                                   ...                 ...
# 419  535  Erikca Maria Rosalina Leal Quisquina          2016-09-28
# 420  536                Rudy Gabriel Ajú López          2015-12-22
# 421  538          Nataly Ileana Leal Quisquina          2014-08-06
# 422  544              Eduardo Valeriano Chávez          2015-07-13
# 423  554       Victor Ehidan Tomás Puac Ulario          2018-09-12
#
#           comunidad sexo monitoreo_prim monitoreo_ult  talla_prim  talla_ult  \
# 0        Los Planes    F     2017-08-15    2019-10-25        70.5       87.3
# 1             Pahaj    M     2017-12-06    2020-01-15        76.4       92.5
# 2             Pahaj    F     2018-10-19    2021-12-08        72.5       95.6
# 3         Xesampual    M     2019-07-03    2021-12-08        62.0       90.0
# 4         Xesampual    M     2019-05-15    2019-07-31        56.4       61.0
# ..              ...  ...            ...           ...         ...        ...
# 419  Ciénaga Grande    F     2019-03-13    2019-04-10        84.7       85.8
# 420  Ciénaga Grande    M     2019-03-13    2019-04-10        85.6       85.8
# 421  Ciénaga Grande    F     2019-03-13    2019-04-10        99.2       99.0
# 422        Nikajkim    M     2019-03-13    2019-04-24        97.0       97.2
# 423          Cruz B    M     2019-03-13    2019-04-10        63.3       64.5
#
#        z_prim  ...  talla_dif     z_dif  monitoreo_prim_edad  duración  \
# 0   -3.219024  ...       16.8  0.083283             1.478439  2.193018
# 1   -3.906698  ...       16.1  1.002280             2.214921  2.108145
# 2   -3.386637  ...       23.1  0.661844             1.730322  3.137577
# 3    0.279202  ...       28.0 -1.240333             0.284736  2.433949
# 4   -3.597655  ...        4.6  0.502948             0.347707  0.210815
# ..        ...  ...        ...       ...                  ...       ...
# 419 -1.493608  ...        1.1  0.111335             2.453114  0.076660
# 420 -3.100616  ...        0.2 -0.077623             3.222450  0.076660
# 421 -1.646368  ...       -0.2 -0.149155             4.599589  0.076660
# 422 -0.861285  ...        0.2 -0.221440             3.665982  0.114990
# 423 -1.232583  ...        1.2 -0.226838             0.498289  0.076660
#
#      z_dif_rate  frecuencia  stunted_at_first  stunted_at_end  age_group  \
# 0      0.037976    4.559925              True            True        1-2
# 1      0.475432    5.217857              True            True        2-3
# 2      0.210941    2.868455              True            True        1-2
# 3     -0.509597    6.573678             False           False        0-1
# 4      2.385739   18.974026              True            True        0-1
# ..          ...         ...               ...             ...        ...
# 419    1.452326   26.089286             False           False        2-3
# 420   -1.012568   26.089286              True            True        3-4
# 421   -1.945679   26.089286             False           False        4-5
# 422   -1.925733   17.392857             False           False        3-4
# 423   -2.959022   26.089286             False           False        0-1
#
#      age_sex_group
# 0      F 1-2 Years
# 1      M 2-3 Years
# 2      F 1-2 Years
# 3      M 0-1 Years
# 4      M 0-1 Years
# ..             ...
# 419    F 2-3 Years
# 420    M 3-4 Years
# 421    F 4-5 Years
# 422    M 3-4 Years
# 423    M 0-1 Years
#
# [424 rows x 22 columns]

# %%
# Create a MultiComparison object, then running a Tukey's HSD test
mc = MultiComparison(mm_data['z_dif_rate'], mm_data['age_sex_group'])
result = mc.tukeyhsd()
print(result)
# Out:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================
#    group1      group2   meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------
# F 0-1 Years F 1-2 Years   0.1558 0.9854 -0.2984   0.61  False
# F 0-1 Years F 2-3 Years   0.3044 0.7475 -0.2395 0.8483  False
# F 0-1 Years F 3-4 Years   0.4837 0.3771  -0.179 1.1464  False
# F 0-1 Years F 4-5 Years   0.5168 0.6319 -0.3246 1.3582  False
# F 0-1 Years M 0-1 Years   0.1041 0.9979 -0.2901 0.4983  False
# F 0-1 Years M 1-2 Years   0.4933 0.0367  0.0154 0.9713   True
# F 0-1 Years M 2-3 Years   0.3256 0.7795 -0.2741 0.9252  False
# F 0-1 Years M 3-4 Years   0.2196 0.9928 -0.4867  0.926  False
# F 0-1 Years M 4-5 Years   0.2368 0.9997 -0.9186 1.3921  False
# F 1-2 Years F 2-3 Years   0.1486 0.9984 -0.4348  0.732  False
# F 1-2 Years F 3-4 Years   0.3279 0.8919 -0.3676 1.0234  False
# F 1-2 Years F 4-5 Years    0.361 0.9477 -0.5064 1.2284  False
# F 1-2 Years M 0-1 Years  -0.0517    1.0 -0.4988 0.3954  False
# F 1-2 Years M 1-2 Years   0.3375 0.5603 -0.1849   0.86  False
# F 1-2 Years M 2-3 Years   0.1698 0.9977 -0.4659 0.8055  False
# F 1-2 Years M 3-4 Years   0.0639    1.0 -0.6733  0.801  False
# F 1-2 Years M 4-5 Years    0.081    1.0 -1.0935 1.2555  False
# F 2-3 Years F 3-4 Years   0.1793 0.9991 -0.5779 0.9364  False
# F 2-3 Years F 4-5 Years   0.2124 0.9993 -0.7052   1.13  False
# F 2-3 Years M 0-1 Years  -0.2003 0.9745 -0.7383 0.3377  False
# F 2-3 Years M 1-2 Years   0.1889 0.9923 -0.4132  0.791  False
# F 2-3 Years M 2-3 Years   0.0212    1.0 -0.6814 0.7238  False
# F 2-3 Years M 3-4 Years  -0.0847    1.0 -0.8803 0.7109  False
# F 2-3 Years M 4-5 Years  -0.0676    1.0 -1.2796 1.1444  False
# F 3-4 Years F 4-5 Years   0.0331    1.0 -0.9595 1.0257  False
# F 3-4 Years M 0-1 Years  -0.3796 0.7122 -1.0374 0.2783  False
# F 3-4 Years M 1-2 Years   0.0096    1.0 -0.7016 0.7208  False
# F 3-4 Years M 2-3 Years  -0.1581 0.9998 -0.9562   0.64  False
# F 3-4 Years M 3-4 Years   -0.264 0.9945 -1.1451  0.617  False
# F 3-4 Years M 4-5 Years  -0.2469 0.9998 -1.5167 1.0228  False
# F 4-5 Years M 0-1 Years  -0.4127 0.8631 -1.2503 0.4249  False
# F 4-5 Years M 1-2 Years  -0.0235    1.0 -0.9036 0.8566  False
# F 4-5 Years M 2-3 Years  -0.1912 0.9998 -1.1429 0.7605  False
# F 4-5 Years M 3-4 Years  -0.2971 0.9956 -1.3194 0.7251  False
# F 4-5 Years M 4-5 Years    -0.28 0.9997 -1.6515 1.0915  False
# M 0-1 Years M 1-2 Years   0.3892 0.2081  -0.082 0.8604  False
# M 0-1 Years M 2-3 Years   0.2215 0.9743 -0.3728 0.8158  False
# M 0-1 Years M 3-4 Years   0.1155    1.0 -0.5862 0.8173  False
# M 0-1 Years M 4-5 Years   0.1327    1.0 -1.0199 1.2853  False
# M 1-2 Years M 2-3 Years  -0.1677 0.9983 -0.8206 0.4851  False
# M 1-2 Years M 3-4 Years  -0.2737 0.9781 -1.0257 0.4783  False
# M 1-2 Years M 4-5 Years  -0.2566 0.9996 -1.4404 0.9273  False
# M 2-3 Years M 3-4 Years  -0.1059    1.0 -0.9406 0.7287  False
# M 2-3 Years M 4-5 Years  -0.0888    1.0 -1.3268 1.1492  False
# M 3-4 Years M 4-5 Years   0.0171    1.0 -1.2759 1.3102  False
# -------------------------------------------------------------

# %%
# ALL VALUES FOR 'REJECT' ARE FALSE EXCEPT FOR THE COMPARISON BETWEEN 0-1 YEAR OLD FEMALES AND 1-2 YEAR OLD MALES; THIS MEANS THAT THERE ARE NO
# STATISTICALLY SIGNIFICANT DIFFERENCES FOR THE RATE OF CHANGE OF HEIGHT-FOR-AGE Z-SCORES BETWEEN THE AGE-SEX GROUPS ASIDES FROM 0-1 YEAR OLD FEMALES AND 
# 1-2 YEAR OLD MALES, WITH THE 1-2 YEAR OLD MALES SHOWING MUCH BETTER PROGRESS THAN THE 0-1 YEAR OLD FEMALES
