# %%
# THE PURPOSE OF THIS SCRIPT IS TO: 

# 1) TAKE IN MIL MILAGROS'S FULL DATASET (CONTAINING A ROW FOR EVERY CHECK-UP) AND THE INDIVIDUAL DATASET (CONTAINING A ROW FOR EVERY
#    CHILD), AND DERIVE ANOTHER TABLE THAT DISPLAYS COMMUNITY-WIDE INFORMATION, SUCH AS YEARS AFFILIATED WITH MIL MILAGROS, TOTAL NUMBER 
#    OF KIDS AND CHECK-UPS, AVERAGE CHANGE IN HEIGHT-FOR-AGE Z-SCORE AMONG ITS KIDS, ETC.

# 2) RUN A STATISTICAL TEST THAT INVESTIGATES WHETHER ANY OF THE COMMUNITIES DIFFER FROM EACH OTHER IN THEIR AVERAGE CHANGE IN HEIGHT-FOR-AGE Z-SCORE

# %%
# IMPORTING PACKAGES
import pandas as pd
import statsmodels.api as sm
from statsmodels.sandbox.stats.multicomp import MultiComparison
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# READING IN DATASET WITH ONE ROW FOR EVERY CHECK-UP
mm_data = pd.read_excel("/Users/ajarbuckle/Desktop/MM PROJECT/mm_data_redo/mm_data_clean.xlsx") 
mm_data
# Out:
#                       nombre_de_la_madre           nombre_del_niño/niña  \
# 0                 Ofelia Gabina Alva Mus         Samuel David Alva Alva
# 1              María Teresa Cos González  Jordy Levni Alfredo López Cos
# 2                  Elsa Griselda Xaminez  Kerman Eliel González Xaminez
# 3                         Cristina Godoy     Eduardo Emilio Ixcol Godoy
# 4                Ana Cristina Chox Ixcol       Domingo Braxton Tay Chox
# ...                                  ...                            ...
# 3779     Carolina Estefany Sajché Zavala     Heredyt Tatiana Noj Sajche
# 3780               Francisca Hilaria Bac           Manuela Claret Tulul
# 3781  Santos Lucrecia López Ixcol de Aju             Nena Recién nacida
# 3782  Santos Lucrecia López Ixcol de Aju             Nena Recién nacida
# 3783  Santos Lucrecia López Ixcol de Aju       Recien Nacida: Aju Lopez
#
#      fecha_de_nacimiento sexo        comunidad fecha_de_monitoreo  peso  \
# 0             2015-09-19    M            Pahaj         2017-12-06   8.7
# 1             2016-08-10    M            Pahaj         2019-01-16  13.3
# 2             2016-03-17    M        Pamezabal         2019-01-16  12.4
# 3             2015-09-21    M  Los Manantiales         2019-04-10  12.2
# 4             2014-06-12    M  Los Manantiales         2019-01-16  15.8
# ...                  ...  ...              ...                ...   ...
# 3779          2019-09-10    F            Pahaj         2019-12-11   5.5
# 3780          2018-10-24    F            Pahaj         2019-01-18   5.4
# 3781          2019-02-26    F   Ciénaga Grande         2019-03-13   2.5
# 3782          2019-02-26    F   Ciénaga Grande         2019-04-10   2.6
# 3783          2019-02-26    F   Ciénaga Grande         2019-03-13   2.5
#
#       talla    edad_a  edad_m  edad_s   ID  puntaje_z
# 0      76.4  2.214921      26     115    2  -3.906698
# 1      81.0  2.433949      29     127    7  -3.039551
# 2      85.5  2.833676      34     147    8  -2.561794
# 3      86.0  3.550992      42     185   11  -3.493355
# 4      97.3  4.596851      55     239   20  -2.228093
# ...     ...       ...     ...     ...  ...        ...
# 3779   58.4  0.251882       3      13  526  -0.654548
# 3780   55.1  0.235455       2      12  495  -1.958459
# 3781   43.0  0.041068       0       2  530  -4.473173
# 3782   45.0  0.117728       1       6  530  -5.064258
# 3783   43.0  0.041068       0       2  558  -4.473173
#
# [3784 rows x 13 columns]

# %%
# CREATING A TEMPORARY TABLE THAT HAS COMMUNITY-WIDE INFORMATION ON INFORMATION NOT RELATED TO INDIVIDUAL CHILDREN
temp1 = mm_data.groupby('comunidad').agg(
    comunidad = ('comunidad', 'first'),
    año_primero = ('fecha_de_monitoreo', lambda x: x.min().year),
    año_último = ('fecha_de_monitoreo', lambda x: x.max().year),
    chequeos_total = ('ID', 'count'), 
    niños_total = ('ID', lambda x: x.nunique())
    )
temp1
# Out:
#                        comunidad  año_primero  año_último  chequeos_total  \
# comunidad
# Campo Verde          Campo Verde         2018        2019              25
# Chuijomil              Chuijomil         2018        2021             218
# Ciénaga Grande    Ciénaga Grande         2019        2021             117
# Cruz B                    Cruz B         2019        2021             301
# Desconocido          Desconocido         2017        2018              12
# Los Manantiales  Los Manantiales         2018        2021             213
# Los Planes            Los Planes         2017        2021             243
# Nikajkim                Nikajkim         2019        2021             281
# Nuevo Progreso    Nuevo Progreso         2014        2021             226
# Pahaj                      Pahaj         2014        2021            1638
# Pamezabal              Pamezabal         2018        2021             268
# Xesampual              Xesampual         2018        2021             242
#
#                  niños_total
# comunidad
# Campo Verde                9
# Chuijomil                 42
# Ciénaga Grande            39
# Cruz B                    61
# Desconocido                6
# Los Manantiales           31
# Los Planes                43
# Nikajkim                  52
# Nuevo Progreso            36
# Pahaj                    209
# Pamezabal                 40
# Xesampual                 30

# %%
# READING IN DATASET WITH ONE ROW FOR EVERY CHILD
mm_data = pd.read_excel("/Users/ajarbuckle/Desktop/MM PROJECT/mm_data_redo/mm_data_individual_table.xlsx") 
mm_data
# Out:
#       ID                       nombre_del_niño fecha_de_nacimiento  \
# 0      1             Maybelin Alicia Aju López          2016-02-22
# 1      2                Samuel David Alva Alva          2015-09-19
# 2      3                      Miriam Tulul Bac          2017-01-25
# 3      4          Cristian Anibal Avila Chávez          2019-03-21
# 4      5             Diego Alejandro Tzaj Chox          2019-01-08
# ..   ...                                   ...                 ...
# 419  535  Erikca Maria Rosalina Leal Quisquina          2016-09-28
# 420  536                Rudy Gabriel Ajú López          2015-12-22
# 421  538          Nataly Ileana Leal Quisquina          2014-08-06
# 422  544              Eduardo Valeriano Chávez          2015-07-13
# 423  554       Victor Ehidan Tomás Puac Ulario          2018-09-12
#
#           comunidad sexo monitoreo_prim monitoreo_ult  talla_prim  talla_ult  \
# 0        Los Planes    F     2017-08-15    2019-10-25        70.5       87.3
# 1             Pahaj    M     2017-12-06    2020-01-15        76.4       92.5
# 2             Pahaj    F     2018-10-19    2021-12-08        72.5       95.6
# 3         Xesampual    M     2019-07-03    2021-12-08        62.0       90.0
# 4         Xesampual    M     2019-05-15    2019-07-31        56.4       61.0
# ..              ...  ...            ...           ...         ...        ...
# 419  Ciénaga Grande    F     2019-03-13    2019-04-10        84.7       85.8
# 420  Ciénaga Grande    M     2019-03-13    2019-04-10        85.6       85.8
# 421  Ciénaga Grande    F     2019-03-13    2019-04-10        99.2       99.0
# 422        Nikajkim    M     2019-03-13    2019-04-24        97.0       97.2
# 423          Cruz B    M     2019-03-13    2019-04-10        63.3       64.5
#
#        z_prim     z_ult  observaciones  talla_dif     z_dif  \
# 0   -3.219024 -3.135741             10       16.8  0.083283
# 1   -3.906698 -2.904418             11       16.1  1.002280
# 2   -3.386637 -2.724794              9       23.1  0.661844
# 3    0.279202 -0.961131             16       28.0 -1.240333
# 4   -3.597655 -3.094706              4        4.6  0.502948
# ..        ...       ...            ...        ...       ...
# 419 -1.493608 -1.382273              2        1.1  0.111335
# 420 -3.100616 -3.178239              2        0.2 -0.077623
# 421 -1.646368 -1.795524              2       -0.2 -0.149155
# 422 -0.861285 -1.082725              2        0.2 -0.221440
# 423 -1.232583 -1.459422              2        1.2 -0.226838
#
#      monitoreo_prim_edad  duración  z_dif_rate  frecuencia  stunted_at_first  \
# 0               1.478439  2.193018    0.037976    4.559925              True
# 1               2.214921  2.108145    0.475432    5.217857              True
# 2               1.730322  3.137577    0.210941    2.868455              True
# 3               0.284736  2.433949   -0.509597    6.573678             False
# 4               0.347707  0.210815    2.385739   18.974026              True
# ..                   ...       ...         ...         ...               ...
# 419             2.453114  0.076660    1.452326   26.089286             False
# 420             3.222450  0.076660   -1.012568   26.089286              True
# 421             4.599589  0.076660   -1.945679   26.089286             False
# 422             3.665982  0.114990   -1.925733   17.392857             False
# 423             0.498289  0.076660   -2.959022   26.089286             False
#
#      stunted_at_end
# 0              True
# 1              True
# 2              True
# 3             False
# 4              True
# ..              ...
# 419           False
# 420            True
# 421           False
# 422           False
# 423           False
#
# [424 rows x 20 columns]

# %%
# CREATING A TEMPORARY TABLE THAT HAS COMMUNITY-WIDE INFORMATION ON INFORMATION RELATED TO INDIVIDUAL CHILDREN
temp2 = mm_data.groupby('comunidad').agg(
    comunidad = ('comunidad', 'first'),
    avg_num_check = ('observaciones', 'mean'),
    avg_duration = ('duración', 'mean'),
    avg_freq = ('frecuencia', 'mean'),
    avg_start_age = ('monitoreo_prim_edad', 'mean'),
    avg_start_z = ('z_prim', 'mean'),
    avg_end_z = ('z_ult', 'mean')
    )

# CREATING A NEW COLUMN IN TEMP2 FOR AVERAGE CHANGE IN HEIGHT-FOR-AGE Z-SCORE PER CHILD
temp2['avg_change_z'] = temp2['avg_end_z'] - temp2['avg_start_z']

# CREATING A COLUMN FOR THE RATE OF HEIGHT-FOR-AGE Z-SCORE CHANGE OVER TIME
temp2['avg_z_dif_rate'] = (temp2['avg_change_z'] / temp2['avg_duration'])

temp2
# Out:
#                        comunidad  avg_num_check  avg_duration   avg_freq  \
# comunidad
# Campo Verde          Campo Verde       2.625000      0.365503   7.446676
# Chuijomil              Chuijomil       6.964286      1.226655   7.327325
# Ciénaga Grande    Ciénaga Grande       4.523810      0.637007  14.100855
# Cruz B                    Cruz B       7.179487      1.166746   8.770915
# Desconocido          Desconocido       6.500000      2.123203   3.184562
# Los Manantiales  Los Manantiales       7.384615      1.278050   9.275086
# Los Planes            Los Planes       8.360000      1.682355   7.282634
# Nikajkim                Nikajkim       6.837838      1.255046   7.797931
# Nuevo Progreso    Nuevo Progreso       8.076923      1.586585   6.288308
# Pahaj                      Pahaj       9.682927      1.743410   7.066669
# Pamezabal              Pamezabal       9.960000      1.398056   7.657958
# Xesampual              Xesampual       9.869565      1.598072   7.582919
#
#                  avg_start_age  avg_start_z  avg_end_z  avg_change_z  \
# comunidad
# Campo Verde           3.220397    -1.313437  -1.310037      0.003400
# Chuijomil             1.568397    -2.156903  -2.327209     -0.170305
# Ciénaga Grande        2.098106    -2.138112  -2.112634      0.025478
# Cruz B                1.276400    -1.754031  -2.046797     -0.292766
# Desconocido           2.510609     0.089988  -1.354337     -1.444325
# Los Manantiales       1.727057    -1.838661  -2.176515     -0.337855
# Los Planes            1.462998    -1.973983  -2.348819     -0.374836
# Nikajkim              1.651812    -1.646646  -1.681127     -0.034481
# Nuevo Progreso        1.295003    -1.716160  -2.364362     -0.648201
# Pahaj                 1.268977    -2.191688  -2.356100     -0.164413
# Pamezabal             1.363888    -2.104325  -1.936329      0.167996
# Xesampual             0.849567    -1.348214  -1.447203     -0.098989
#
#                  avg_z_dif_rate
# comunidad
# Campo Verde            0.009302
# Chuijomil             -0.138837
# Ciénaga Grande         0.039996
# Cruz B                -0.250925
# Desconocido           -0.680258
# Los Manantiales       -0.264352
# Los Planes            -0.222804
# Nikajkim              -0.027474
# Nuevo Progreso        -0.408551
# Pahaj                 -0.094305
# Pamezabal              0.120164
# Xesampual             -0.061943

# %%
# PUTTING THE TWO TEMPORARY TABLES TOGETHER TO ARRIVE AT THE FINAL DATAFRAME
# IT WAS NECESSARY TO FIRST RESET THE INDICES OF THE TEMPORARY TABLES SO THE MERGE FUNCTION WOULD WORK
temp1 = temp1.reset_index(drop=True)
temp2 = temp2.reset_index(drop=True)
final_table = pd.merge(temp1, temp2, left_on='comunidad', right_on='comunidad', how = 'outer')

# ROUNDING COLUMN VALUES TO MAKE THE FINAL TABLE LOOK NICER 
columns_to_round = ['avg_num_check', 'avg_duration', 'avg_freq', 'avg_start_age', 'avg_start_z', 'avg_end_z', 'avg_change_z', 'avg_z_dif_rate']
final_table[columns_to_round] = final_table[columns_to_round].round(2)

final_table
# Out:
#           comunidad  año_primero  año_último  chequeos_total  niños_total  \
# 0       Campo Verde         2018        2019              25            9
# 1         Chuijomil         2018        2021             218           42
# 2    Ciénaga Grande         2019        2021             117           39
# 3            Cruz B         2019        2021             301           61
# 4       Desconocido         2017        2018              12            6
# 5   Los Manantiales         2018        2021             213           31
# 6        Los Planes         2017        2021             243           43
# 7          Nikajkim         2019        2021             281           52
# 8    Nuevo Progreso         2014        2021             226           36
# 9             Pahaj         2014        2021            1638          209
# 10        Pamezabal         2018        2021             268           40
# 11        Xesampual         2018        2021             242           30
#
#     avg_num_check  avg_duration  avg_freq  avg_start_age  avg_start_z  \
# 0            2.62          0.37      7.45           3.22        -1.31
# 1            6.96          1.23      7.33           1.57        -2.16
# 2            4.52          0.64     14.10           2.10        -2.14
# 3            7.18          1.17      8.77           1.28        -1.75
# 4            6.50          2.12      3.18           2.51         0.09
# 5            7.38          1.28      9.28           1.73        -1.84
# 6            8.36          1.68      7.28           1.46        -1.97
# 7            6.84          1.26      7.80           1.65        -1.65
# 8            8.08          1.59      6.29           1.30        -1.72
# 9            9.68          1.74      7.07           1.27        -2.19
# 10           9.96          1.40      7.66           1.36        -2.10
# 11           9.87          1.60      7.58           0.85        -1.35
#
#     avg_end_z  avg_change_z  avg_z_dif_rate
# 0       -1.31          0.00            0.01
# 1       -2.33         -0.17           -0.14
# 2       -2.11          0.03            0.04
# 3       -2.05         -0.29           -0.25
# 4       -1.35         -1.44           -0.68
# 5       -2.18         -0.34           -0.26
# 6       -2.35         -0.37           -0.22
# 7       -1.68         -0.03           -0.03
# 8       -2.36         -0.65           -0.41
# 9       -2.36         -0.16           -0.09
# 10      -1.94          0.17            0.12
# 11      -1.45         -0.10           -0.06

# %%
# NOW GOING BACK TO THE DATASET WITH ONE ROW PER CHILD TO RUN THE STATISTICAL TEST TO SEE IF THERE ARE STATISTICALLY SIGNIFICANT DIFFERENCES IN RATE OF CHANGE 
# OF HEIGHT-FOR-AGE Z-SCORE OVER TIME BETWEEN COMMUNITIES 

mm_data = pd.read_excel("/Users/ajarbuckle/Desktop/MM PROJECT/mm_data_redo/mm_data_individual_table.xlsx") 
mm_data
# Out:
#       ID                       nombre_del_niño fecha_de_nacimiento  \
# 0      1             Maybelin Alicia Aju López          2016-02-22
# 1      2                Samuel David Alva Alva          2015-09-19
# 2      3                      Miriam Tulul Bac          2017-01-25
# 3      4          Cristian Anibal Avila Chávez          2019-03-21
# 4      5             Diego Alejandro Tzaj Chox          2019-01-08
# ..   ...                                   ...                 ...
# 419  535  Erikca Maria Rosalina Leal Quisquina          2016-09-28
# 420  536                Rudy Gabriel Ajú López          2015-12-22
# 421  538          Nataly Ileana Leal Quisquina          2014-08-06
# 422  544              Eduardo Valeriano Chávez          2015-07-13
# 423  554       Victor Ehidan Tomás Puac Ulario          2018-09-12
#
#           comunidad sexo monitoreo_prim monitoreo_ult  talla_prim  talla_ult  \
# 0        Los Planes    F     2017-08-15    2019-10-25        70.5       87.3
# 1             Pahaj    M     2017-12-06    2020-01-15        76.4       92.5
# 2             Pahaj    F     2018-10-19    2021-12-08        72.5       95.6
# 3         Xesampual    M     2019-07-03    2021-12-08        62.0       90.0
# 4         Xesampual    M     2019-05-15    2019-07-31        56.4       61.0
# ..              ...  ...            ...           ...         ...        ...
# 419  Ciénaga Grande    F     2019-03-13    2019-04-10        84.7       85.8
# 420  Ciénaga Grande    M     2019-03-13    2019-04-10        85.6       85.8
# 421  Ciénaga Grande    F     2019-03-13    2019-04-10        99.2       99.0
# 422        Nikajkim    M     2019-03-13    2019-04-24        97.0       97.2
# 423          Cruz B    M     2019-03-13    2019-04-10        63.3       64.5
#
#        z_prim     z_ult  observaciones  talla_dif     z_dif  \
# 0   -3.219024 -3.135741             10       16.8  0.083283
# 1   -3.906698 -2.904418             11       16.1  1.002280
# 2   -3.386637 -2.724794              9       23.1  0.661844
# 3    0.279202 -0.961131             16       28.0 -1.240333
# 4   -3.597655 -3.094706              4        4.6  0.502948
# ..        ...       ...            ...        ...       ...
# 419 -1.493608 -1.382273              2        1.1  0.111335
# 420 -3.100616 -3.178239              2        0.2 -0.077623
# 421 -1.646368 -1.795524              2       -0.2 -0.149155
# 422 -0.861285 -1.082725              2        0.2 -0.221440
# 423 -1.232583 -1.459422              2        1.2 -0.226838
#
#      monitoreo_prim_edad  duración  z_dif_rate  frecuencia  stunted_at_first  \
# 0               1.478439  2.193018    0.037976    4.559925              True
# 1               2.214921  2.108145    0.475432    5.217857              True
# 2               1.730322  3.137577    0.210941    2.868455              True
# 3               0.284736  2.433949   -0.509597    6.573678             False
# 4               0.347707  0.210815    2.385739   18.974026              True
# ..                   ...       ...         ...         ...               ...
# 419             2.453114  0.076660    1.452326   26.089286             False
# 420             3.222450  0.076660   -1.012568   26.089286              True
# 421             4.599589  0.076660   -1.945679   26.089286             False
# 422             3.665982  0.114990   -1.925733   17.392857             False
# 423             0.498289  0.076660   -2.959022   26.089286             False
#
#      stunted_at_end
# 0              True
# 1              True
# 2              True
# 3             False
# 4              True
# ..              ...
# 419           False
# 420            True
# 421           False
# 422           False
# 423           False
#
# [424 rows x 20 columns]

# %%
# Create a MultiComparison object, then running a Tukey's HSD test
mc = MultiComparison(mm_data['z_dif_rate'], mm_data['comunidad'])
result = mc.tukeyhsd()
print(result)
# Out:
#          Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================================
#      group1          group2     meandiff p-adj   lower  upper  reject
# ---------------------------------------------------------------------
#     Campo Verde       Chuijomil  -0.3855 0.9942 -1.5279  0.757  False
#     Campo Verde  Ciénaga Grande   0.0701    1.0 -1.1139 1.2541  False
#     Campo Verde          Cruz B  -0.3634 0.9954 -1.4695 0.7427  False
#     Campo Verde     Desconocido  -0.5781 0.9995 -2.8311 1.6749  False
#     Campo Verde Los Manantiales  -0.0284    1.0 -1.1806 1.1238  False
#     Campo Verde      Los Planes  -0.1207    1.0 -1.2783 1.0369  False
#     Campo Verde        Nikajkim   0.0161    1.0 -1.0951 1.1272  False
#     Campo Verde  Nuevo Progreso  -0.4356 0.9851 -1.5878 0.7166  False
#     Campo Verde           Pahaj  -0.1711    1.0 -1.2029 0.8608  False
#     Campo Verde       Pamezabal   0.0343    1.0 -1.1233 1.1919  False
#     Campo Verde       Xesampual    0.117    1.0 -1.0528 1.2867  False
#       Chuijomil  Ciénaga Grande   0.4555 0.8062 -0.3671 1.2782  False
#       Chuijomil          Cruz B   0.0221    1.0 -0.6838  0.728  False
#       Chuijomil     Desconocido  -0.1926    1.0 -2.2785 1.8932  False
#       Chuijomil Los Manantiales   0.3571 0.9367 -0.4191 1.1332  False
#       Chuijomil      Los Planes   0.2648 0.9942 -0.5194 1.0489  False
#       Chuijomil        Nikajkim   0.4015 0.7897 -0.3123 1.1153  False
#       Chuijomil  Nuevo Progreso  -0.0502    1.0 -0.8263  0.726  False
#       Chuijomil           Pahaj   0.2144 0.9881 -0.3683 0.7971  False
#       Chuijomil       Pamezabal   0.4197 0.8388 -0.3644 1.2039  False
#       Chuijomil       Xesampual   0.5024 0.6521 -0.2996 1.3044  False
#  Ciénaga Grande          Cruz B  -0.4335 0.7907 -1.2048 0.3379  False
#  Ciénaga Grande     Desconocido  -0.6482 0.9974 -2.7571 1.4607  False
#  Ciénaga Grande Los Manantiales  -0.0985    1.0 -0.9346 0.7376  False
#  Ciénaga Grande      Los Planes  -0.1908 0.9999 -1.0343 0.6528  False
#  Ciénaga Grande        Nikajkim   -0.054    1.0 -0.8326 0.7246  False
#  Ciénaga Grande  Nuevo Progreso  -0.5057 0.7014 -1.3418 0.3304  False
#  Ciénaga Grande           Pahaj  -0.2412 0.9888 -0.9017 0.4193  False
#  Ciénaga Grande       Pamezabal  -0.0358    1.0 -0.8794 0.8077  False
#  Ciénaga Grande       Xesampual   0.0469    1.0 -0.8133  0.907  False
#          Cruz B     Desconocido  -0.2147    1.0 -2.2809 1.8514  False
#          Cruz B Los Manantiales    0.335 0.9327 -0.3865 1.0565  False
#          Cruz B      Los Planes   0.2427 0.9949 -0.4874 0.9728  False
#          Cruz B        Nikajkim   0.3794 0.7544 -0.2746 1.0335  False
#          Cruz B  Nuevo Progreso  -0.0722    1.0 -0.7938 0.6493  False
#          Cruz B           Pahaj   0.1923 0.9849 -0.3154    0.7  False
#          Cruz B       Pamezabal   0.3977 0.8227 -0.3325 1.1278  False
#          Cruz B       Xesampual   0.4803 0.6178 -0.2689 1.2296  False
#     Desconocido Los Manantiales   0.5497 0.9994 -1.5415 2.6409  False
#     Desconocido      Los Planes   0.4574 0.9999 -1.6368 2.5516  False
#     Desconocido        Nikajkim   0.5942 0.9986 -1.4747  2.663  False
#     Desconocido  Nuevo Progreso   0.1425    1.0 -1.9487 2.2337  False
#     Desconocido           Pahaj    0.407    1.0 -1.6203 2.4344  False
#     Desconocido       Pamezabal   0.6124 0.9984 -1.4818 2.7065  False
#     Desconocido       Xesampual   0.6951 0.9951 -1.4058  2.796  False
# Los Manantiales      Los Planes  -0.0923    1.0 -0.8906  0.706  False
# Los Manantiales        Nikajkim   0.0445    1.0 -0.6848 0.7737  False
# Los Manantiales  Nuevo Progreso  -0.4072 0.8705 -1.1976 0.3832  False
# Los Manantiales           Pahaj  -0.1427 0.9998 -0.7442 0.4589  False
# Los Manantiales       Pamezabal   0.0627    1.0 -0.7356 0.8609  False
# Los Manantiales       Xesampual   0.1454    1.0 -0.6704 0.9611  False
#      Los Planes        Nikajkim   0.1368    1.0  -0.601 0.8746  False
#      Los Planes  Nuevo Progreso  -0.3149 0.9792 -1.1132 0.4833  False
#      Los Planes           Pahaj  -0.0504    1.0 -0.6622 0.5615  False
#      Los Planes       Pamezabal    0.155    1.0 -0.6511  0.961  False
#      Los Planes       Xesampual   0.2377 0.9985 -0.5857  1.061  False
#        Nikajkim  Nuevo Progreso  -0.4517 0.6686  -1.181 0.2776  False
#        Nikajkim           Pahaj  -0.1871 0.9898 -0.7058 0.3315  False
#        Nikajkim       Pamezabal   0.0182    1.0 -0.7196  0.756  False
#        Nikajkim       Xesampual   0.1009    1.0 -0.6558 0.8576  False
#  Nuevo Progreso           Pahaj   0.2646 0.9536  -0.337 0.8661  False
#  Nuevo Progreso       Pamezabal   0.4699 0.7366 -0.3284 1.2682  False
#  Nuevo Progreso       Xesampual   0.5526 0.5312 -0.2632 1.3683  False
#           Pahaj       Pamezabal   0.2053 0.9944 -0.4065 0.8172  False
#           Pahaj       Xesampual    0.288 0.9422 -0.3465 0.9226  False
#       Pamezabal       Xesampual   0.0827    1.0 -0.7407 0.9061  False
# ---------------------------------------------------------------------

# %%
# ALL VALUES FOR 'REJECT' ARE FALSE, MEANING THAT THERE ARE NO STATISTICALLY SIGNIFICANT DIFFERENCES FOR THE RATE OF CHANGE OF HEIGHT-FOR-AGE Z-SCORES
# BETWEEN THE COMMUNITIES
